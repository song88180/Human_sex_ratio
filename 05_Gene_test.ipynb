# %%
library(sumFREGAT)

# %%
SKATO(score.file = 'WLS.vcf.gz', gene.file = "refFlat_uniq_filtered.txt", cor.path = './SNP_cor_matrix/all',
     write.file = 'results/SKATO.txt', quiet = FALSE, beta.par=c(1,1))
# Out:
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No matching variants in correlation file for gene A2M, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No matching variants in correlation file for gene A2ML1, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No matching variants in correlation file for gene ABCA2, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No matching variants in correlation file for gene ACSM4, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No variants to analyze in gene AGAP4, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# “No matching variants in correlation file for gene AICDA, skipped”
# Warning message in get.sumstat(score.file, gene.file, gene, anno.type, cor.path, :
# ...
